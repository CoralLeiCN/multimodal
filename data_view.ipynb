# %%
import pandas as pd

# %%
  df = pd.read_parquet("data/gold/object_records.parquet", engine="pyarrow")

  print(df.shape)  # (150337, 11)
# Out:
# (150337, 11)

# %%
df.nunique()
# Out:
# uid            150337
# identifier     150337
# title          102352
# description    135399
# category          180
# material        24906
# object_name     19060
# date             8131
# place            3477
# maker           22455
# image          149237
# dtype: int64

# %%
uv run --package multimodal-backend cronjob/index_images.py --resume f3ea37d7aab34524
